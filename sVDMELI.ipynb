# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
basepath = "C:/Users/jpquinte/Documents/notebooks_prueba"

# %%
Primer_informeComercial = basepath + "/InformeComercial.xlsx"
dfint = pd.read_excel(Primer_informeComercial , sheet_name="Sheet1")
dfint.head()
# Out:
# c:\Users\jpquinte\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Base Application Nro Solicitud  Cedula Cliente  \
# 0          12513296    OM12518204      1152469775
# 1          12513308    OM12518216      1005772747
# 2          12513336    OM12518244      1018457239
# 3          12513358    OM12518266      1130681816
# 4          12513362    OM12518270        71373029
#
#                      Nombre Cliente                       Asesor Sufi  \
# 0    JORGE ALEXANDER SANCHEZ MEDINA  Andreina del Carmen Pacheco Rada
# 1                Juan  Leonel Perez        Carlos Augusto Cano Correa
# 2       MONICA LUCIA VEGA CONTRERAS          Laura Fernanda Mesa Vega
# 3      HECTOR FABIO SANCHEZ ESCOBAR     Adriana Macela Vega Benavides
# 4  RODRIGO ALBERTO MONSALVE GALEANO         Esteban Atehortua Agudelo
#
# ...

# %%
#dtfiltradosVDmeli= dfint[(dfint["Nombre de la feria"].str.contains("VDMELI", case=False))]

dfOrdenadoFechaRadicacion = dfint.sort_values(by='Fecha Radicacion', ascending=False)
dfFiltradoVDMELI= dfOrdenadoFechaRadicacion[(dfint['Nombre de la feria'] == 'VDMELI')]
dfFiltrado_creador = dfFiltradoVDMELI [(dfFiltradoVDMELI["Creador de la solicitud"].str.contains("Venta Digital Sufi",case=False))]
# Out:
# C:\Users\jpquinte\AppData\Local\Temp\ipykernel_13040\2238770600.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfFiltradoVDMELI= dfOrdenadoFechaRadicacion[(dfint['Nombre de la feria'] == 'VDMELI')]

# %%
dfFiltrado_creador.to_excel("VDMELI.xlsx")
