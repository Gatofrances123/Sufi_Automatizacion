# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#2 Vamos a importar la ruta del excel con la palabra "basepath "
basepath = "C:/Users/jpquinte/Documents/notebooks_prueba"

# %%
#Define el nombre de archivo en cuestion 
Primer_informeComercial = basepath + "/InformeComercial.xlsx"

# %%
#cargar archivoa dataframe( Leer el archivo )
dfint = pd.read_excel(Primer_informeComercial , sheet_name="Sheet1")
dfint.head()
# Out:
# c:\Users\jpquinte\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Base Application Nro Solicitud  Cedula Cliente  \
# 0          11645806    OM11650630        42825810
# 1          11737274    OM11742126        80174937
# 2          11968854    OM11973707        91532917
# 3          11750893    OM11755747        79778468
# 4          12031895    OM12036752      1152219566
#
#                        Nombre Cliente                      Asesor Sufi  \
# 0  ISABEL CRISTINA CEBALLOS CASTAÑEDA                              NaN
# 1     URIEL ANTONIO BUITRAGO VALBUENA       Yovanna Salamanca Lizarazo
# 2     FABIAN LIBARDO SANDOVAL REATIGA     Andrea Lizeth Prada Lizarazo
# 3    GUSTAVO ADOLFO MARISCAL PALENCIA  Jhon Fredy Beltran Castelblanco
# 4             NATALIA RAMIREZ CARDONA  CLAUDIA ANDREA BOLIVAR COLORADO
#
# ...

# %%
#CONDICION POR COINCIDENCIAPARCIAL : 
dtfiltradosEcosistemas = dfint[(dfint["Nombre Canal"].str.contains("ECOSISTEMA", case=False))]
dtfiltradosEcosistemas.head()
# Out:
#      Base Application Nro Solicitud  Cedula Cliente  \
# 23           12349391    OM12354299        43928092
# 24           12010986    OM12015843        31579039
# 40           12051566    OM12056423        43837940
# 119          12463953    OM12468861        71771945
# 123          11647755    OM11652579        80094588
#
#                    Nombre Cliente                 Asesor Sufi  \
# 23         Maria  Ortega Restrepo  Carlos Augusto Cano Correa
# 24   LEIDY LAURA QUINTERO AGUIRRE  Carlos Augusto Cano Correa
# 40   SANDRA PATRICIA LOPEZ ZULETA  Carlos Augusto Cano Correa
# 119      Angel  Atehortua Agudelo  Carlos Augusto Cano Correa
# 123    WILSON FIGUEROA CHIPATECUA  Carlos Augusto Cano Correa
#
#                Nombre Canal                     NombreOficina Nombre Vendedor  \
# 23   ECOSISTEMA BANCOLOMBIA  Ecosistema Bancolombia Antioquia    Sufi directo
# 24   ECOSISTEMA BANCOLOMBIA  Ecosistema Bancolombia Antioquia    Sufi directo
# ...

# %%
#fecha de radicacion dtfiltradosEcosistemas
dfOFechaRadicacion = dtfiltradosEcosistemas.sort_values(by='Fecha Radicacion', ascending=False)

# %%
dfFiltrado_creador = dfOFechaRadicacion [(dfOFechaRadicacion["Creador de la solicitud"].str.contains("Venta Digital Sufi",case=False))]

# %%
#Exportar a excel 
dfFiltrado_creador.to_excel("FiltradoEcosistemas.xlsx")
